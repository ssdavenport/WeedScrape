# %%
from bs4 import BeautifulSoup
import urllib
import re

# %%
# load XML file, import to BS object
leafly1path = "/Users/sdavenpo/Google Drive (stevenseandavenport@gmail.com)/3. Dport Research/Projects/Weed Scrape/data/leafly dispensary-info-1 2.28.18.xml"
data = open(leafly1path, 'r').read()
soup = BeautifulSoup(data, 'html.parser')

# %%
# Get URL nodes (list)
letters = soup.find_all("url") 
# Extract text for each element -> list
links = [ x.get_text() for x in letters]

# %%
# Repeat for second half of sitemap
leafly2path = "/Users/sdavenpo/Google Drive (stevenseandavenport@gmail.com)/3. Dport Research/Projects/Weed Scrape/data/leafly dispensary-info-2 2.28.18.xml"
data2 = open(leafly2path, 'r').read()
soup2 = BeautifulSoup(data2, 'html.parser')
letters2 = soup2.find_all("url") 
links = [ x.get_text() for x in letters] + [ x.get_text() for x in letters2]
# Perform regex on URLs to narrow them down.
# I want to find anything after dispensary-info/.../ and remove it!
# TO remove redundant links, grab all of URL up to home page level.
# Get everything to the left of the first / after "info/".
links = [re.compile('(?=nfo)!n.*/.*/').sub('', link) for link in links]

# %%
# Scrape a sample dispensary page
r = urllib.urlopen(links[2]).read()
soup = BeautifulSoup(r)

# Get divs with itemprop=='address'
address = soup.find('div', attrs={"itemprop" : "address"}).get_text()
join_time = soup.find("time").get_text()
reviews = soup.find('span', attrs={"itemprop" : "ratingCount"}).get_text()

dict = {"address":address,
        "joined":join_time,
        "reviews":reviews}
# Out:
# /anaconda2/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /anaconda2/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
dict_list = []

for link in links[:20]:
    
    soup = BeautifulSoup(urllib.urlopen(link).read())

    try: 
        address = soup.find('div', attrs={"itemprop" : "address"}).get_text()
    except:
        address = ""
    try: 
        join_time = soup.find("time").get_text()
    except:
        join_time = ""
    try: 
        reviews = soup.find('span', attrs={"itemprop" : "ratingCount"}).get_text()
    except:
        reviews = ""

    dict = {"url":link,
            "address":address,
            "joined":join_time,
            "reviews":reviews,
            "soup": soup}
    
    dict_list.append(dict)

# %%
# Turn that into a pandas data.frame
import pandas as pd
import csv
store_data = pd.DataFrame(dict_list)
store_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>address</th>
#       <th>joined</th>
#       <th>reviews</th>
#       <th>soup</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>\n\n12059 Aurora Ave NorthLook for the HUGE Gr...</td>
#       <td>4/23/2015 4:44 PM</td>
#       <td>175</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/seattle...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>\n\nSanta Ana, CA\n\n</td>
#       <td>6/26/2017 10:29 PM</td>
#       <td>351</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/stoney-app</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>\n\n4160 SW 109th AVE Between Home Depot and T...</td>
#       <td>2/12/2015 8:41 PM</td>
#       <td>1674</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/growing...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>\n\n17417 SE McLoughlin BlvdPortland, OR\n\n</td>
#       <td>1/5/2014 8:58 PM</td>
#       <td>1386</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/maritim...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/blue-sk...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>\n\n605 E Francis AveSpokane, WA\n\n</td>
#       <td>11/1/2014 3:51 AM</td>
#       <td>780</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/cannabi...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>\n\n8201 SE Powell BlvdFPortland, OR\n\n</td>
#       <td>6/17/2014 9:23 PM</td>
#       <td>1060</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/puddletown</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>\n\n409 Rainier Ave NorthRenton, WA\n\n</td>
#       <td>3/18/2015 7:50 PM</td>
#       <td>585</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/the-eve...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>\n\n6814 NE GlisanPortland, OR\n\n</td>
#       <td>3/25/2014 6:22 PM</td>
#       <td>935</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/the-gre...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>\n\n340 River RoadEugene, OR\n\n</td>
#       <td>1/25/2016 9:14 PM</td>
#       <td>723</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/nectar-...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>\n\n1300 NW 9th StCorvallis, OR\n\n</td>
#       <td>4/22/2014 11:13 PM</td>
#       <td>1311</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/high-qu...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>\n\nAurora, CO\n\n</td>
#       <td>7/22/2015 10:49 PM</td>
#       <td>1265</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/lightsh...</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>\n\n3609 SE Division StreetPortland, OR\n\n</td>
#       <td>7/25/2013 3:53 AM</td>
#       <td>945</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/brother...</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>\n\n12833 Martin Luther King Jr. Way SSeattle,...</td>
#       <td>4/21/2015 4:51 PM</td>
#       <td>1629</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/have-a-...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>\n\nVancouver, BC CA\n\n</td>
#       <td>3/2/2017 8:43 PM</td>
#       <td>962</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/buymywe...</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>\n\n115 Blanchard StSeattle, WA\n\n</td>
#       <td>3/15/2012 7:38 PM</td>
#       <td>969</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/have-a-...</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>\n\n1019 NE 122nd Ave.Portland, OR\n\n</td>
#       <td>8/27/2014 6:03 PM</td>
#       <td>1347</td>
#       <td>&lt;!DOCTYPE html&gt;
# &lt;html data-ng-class="{'navigat...</td>
#       <td>https://www.leafly.com/dispensary-info/nectar-2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
store_data.to_csv("output/store_data.csv")

# %%
# Out:
# '/Users/sdavenpo/Google Drive (stevenseandavenport@gmail.com)/3. Dport Research/Projects/Weed Scrape'
